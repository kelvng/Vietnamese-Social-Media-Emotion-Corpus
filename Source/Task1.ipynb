# %%
# !pip install lxml

import pandas as pd
import json
import os
import sys
import time

import lxml.html
import requests
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.2.6)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
YOUTUBE_COMMENTS_AJAX_URL = 'https://www.youtube.com/comment_service_ajax'

USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'

SORT_BY_POPULAR = 0
SORT_BY_RECENT = 1

FILE_NAME = 'ytb_comments.csv'

# %%
def find_value(html, key, num_chars=2, separator='"'):
    pos_begin = html.find(key) + len(key) + num_chars
    pos_end = html.find(separator, pos_begin)
    return html[pos_begin: pos_end]

# %%
def ajax_request(session, url, params=None, data=None, headers=None, retries=5, sleep=20):
    for _ in range(retries):
        response = session.post(url, params=params, data=data, headers=headers)
        if response.status_code == 200:
            return response.json()
        if response.status_code in [403, 413]:
            return {}
        else:
            time.sleep(sleep)

# %%
def download_comments(youtube_video_url, sort_by=SORT_BY_RECENT, sleep=.1):
    session = requests.Session()
    session.headers['User-Agent'] = USER_AGENT

    response = session.get(youtube_video_url)
    html = response.text
    session_token = find_value(html, 'XSRF_TOKEN', 3)
    session_token = session_token.encode('ascii').decode('unicode-escape')

    data = json.loads(find_value(html, 'var ytInitialData = ', 0, '};') + '}')
    for renderer in search_dict(data, 'itemSectionRenderer'):
        ncd = next(search_dict(renderer, 'nextContinuationData'), None)
        if ncd:
            break

    if not ncd:
        # Comments disabled?
        return

    needs_sorting = sort_by != SORT_BY_POPULAR
    continuations = [(ncd['continuation'], ncd['clickTrackingParams'], 'action_get_comments')]
    while continuations:
        continuation, itct, action = continuations.pop()
        response = ajax_request(session, YOUTUBE_COMMENTS_AJAX_URL,
                                params={action: 1,
                                        'pbj': 1,
                                        'ctoken': continuation,
                                        'continuation': continuation,
                                        'itct': itct},
                                data={'session_token': session_token},
                                headers={'X-YouTube-Client-Name': '1',
                                         'X-YouTube-Client-Version': '2.20201202.06.01'})

        if not response:
            break
        if list(search_dict(response, 'externalErrorMessage')):
            raise RuntimeError('Error returned from server: ' + next(search_dict(response, 'externalErrorMessage')))

        if needs_sorting:
            sort_menu = next(search_dict(response, 'sortFilterSubMenuRenderer'), {}).get('subMenuItems', [])
            if sort_by < len(sort_menu):
                ncd = sort_menu[sort_by]['continuation']['reloadContinuationData']
                continuations = [(ncd['continuation'], ncd['clickTrackingParams'], 'action_get_comments')]
                needs_sorting = False
                continue
            raise RuntimeError('Failed to set sorting')

        if action == 'action_get_comments':
            section = next(search_dict(response, 'itemSectionContinuation'), {})
            for continuation in section.get('continuations', []):
                ncd = continuation['nextContinuationData']
                continuations.append((ncd['continuation'], ncd['clickTrackingParams'], 'action_get_comments'))
            for item in section.get('contents', []):
                continuations.extend([(ncd['continuation'], ncd['clickTrackingParams'], 'action_get_comment_replies')
                                      for ncd in search_dict(item, 'nextContinuationData')])

        elif action == 'action_get_comment_replies':
            continuations.extend([(ncd['continuation'], ncd['clickTrackingParams'], 'action_get_comment_replies')
                                  for ncd in search_dict(response, 'nextContinuationData')])

        for comment in search_dict(response, 'commentRenderer'):
            yield {'text': ''.join([c['text'] for c in comment['contentText']['runs']])}

        time.sleep(sleep)

# %%
def search_dict(partial, search_key):
    stack = [partial]
    while stack:
        current_item = stack.pop()
        if isinstance(current_item, dict):
            for key, value in current_item.items():
                if key == search_key:
                    yield value
                else:
                    stack.append(value)
        elif isinstance(current_item, list):
            for value in current_item:
                stack.append(value)

# %%
def main(url,k):
    FILE_NAME='cmt-link-'+str(k)+'.csv'
    FILE_zip='cmt-link-'+str(k)+'.zip'
    df_comment = pd.DataFrame()
    try:
        youtube_url = url
        limit = 100

        print('Downloading Youtube comments for video:', youtube_url)

        count = 0

        start_time = time.time()

        for comment in download_comments(youtube_url):

            df_comment = df_comment.append(comment, ignore_index=True)

            # comments overview
            comment_json = json.dumps(comment, ensure_ascii=False)
            # print(comment_json)

            count += 1

            if limit and count >= limit:
                break
        compression_opts = dict(method='zip',
                        archive_name=FILE_NAME)  
        df_comment.to_csv(FILE_zip, encoding='utf-16', index=False,
                  compression=compression_opts)
        print(df_comment)
        print('\n[{:.2f} seconds] Done!'.format(time.time() - start_time))

    except Exception as e:
        print('Error:', str(e))
        sys.exit(1)

# %%
"""Dump to a csv from a a list with video links"""
ytb_video_list = ['https://www.youtube.com/watch?v=6rAGEqjuS-0',
                  'https://www.youtube.com/watch?v=2FxxctKIE0c',
                  'https://www.youtube.com/watch?v=UTjyYdmdcKw']

for k in range(len(ytb_video_list)):
    main(ytb_video_list[k],k)
# Out:
# Downloading Youtube comments for video: https://www.youtube.com/watch?v=6rAGEqjuS-0
#                                                  text
# 0   Anh có tể cố gắng làm thêm về cái này không và...
# 1                                 Anh tuân là anh lào
# 2                                6:22 goob bye Tuân 😞
# 3   Góc xin review: a Tuân cho e hỏi bộ sofa a mua...
# 4   em may mắn hơn anh là vợ em nó sợ ma nên đíu b...
# 5                                             😹😹😹😹😹😹😹
# 6   Đây...rồi, cuối c ùng cũng đc xem đợi 1 tuồn m...
# 7      Xem clip ạn Tuân để lấy ngôn từ nói chuyện 😁😆😆
# 8       2:51 hơi liều đấy anh bạn, cẩn thận cái mồm 🤣
# 9   Sau khi xem xong ba tập của cái series này thì...
# 10  Ối giời ơi anh chịu đựng giỏi vậy gặp người kh...
# 11        Chú Tuân ơi chú đẹp zai quá cháu yêu vợ chú
# 12                           quả này thì hết đường về
# 13                                          Má nó hài
# 14  Chị Cừu nhà ta sống bay bổng "lãng mạn"  tới m...
# 15                         3:01 vợ nào chồng nấy :)))
# 16           giọng anh nghe gióng Ăn sập HÀ Nội ghê á
# 17                              Sắp 1tr view r chú ơi
# 18  Uầy, thế này khỏi lấy vợ luôn nhỉ anh:))? Nghe...
# 19  Chuyện kể từ năm ngoái trên live stream nay dự...
# 20                                Cháu chờ chú kể mãi
# 21                                              Hí ah
# 22                                  Đau thương bi đát
# 23                                    Còn sống ko anh
# 24                                            Yêu a(:
# 25                      Anh tuna ơi ! Sofa chờ anh 👍🏻
# 26                                        Đợi mãi :))
# 27                 Video năm nay nói chuyện năm ngoái
# 28              Xong video liệu anh còn sống không😂😂😂
# 29                                             Lô anh
# 30  Anh cố sống đến tập phim thứ N anh nhớ \nANH N...
# 31  Like thứ 999 này chú tuân ơi ;-; cho cháu lên ...
# 32  Mún biết dung nhan của người đàn bà mất não qu...
# 33         1 triệu người đăng ký show mặt chị cừu đi.
# 34                                     Thiêud liêm sỉ
# 92                                      Chơi gay đi a
# 93                      Ạnh cho chị nhà lên tv đi anh
# 94                                               Lô a
# 95  Chú tuna ơi cháu yêu chú cho cháu lên tivi với...
# 96  Anh có cay ko?\nCó\nAnh có làm được gì không?\...
# 97                                               Ờ hở
# 98  anh chơi thử game night with peashooters đi an...
# 99                   Mong anh ra nhiều video hơn 👉👈😄😄
#
# [1.76 seconds] Done!
# Downloading Youtube comments for video: https://www.youtube.com/watch?v=2FxxctKIE0c
#                                                  text
# 0   Bây giờ thì Trung quốc ko còn đồng chí ,anh em...
# 1                                Rất hay và chân thực
# 2   Tôi cảm nhận là Trung Quốc đang thay đổi Chiến...
# 3                   Có ơn trả ơn, có oán thì trả oán.
# 4   Trung quốc nó giúp việt nam để trở thành   tri...
# 5   Các thị xã vùng biên bị bạn tàn phá nặng nề. B...
# 6              1949 Tq mới có quốc khánh ssu vn 4 năm
# 7   Ai có link bài này cho mình xin để khi nào gặp...
# 8   Càng hiểu biết nhiều về lịch sử càng thấy nhữn...
# 9   Đừng nói ngày xưa mà là hiện tại luôn lúc bùng...
# 10  Bạn nên để đg link của bài viết và sao chép lạ...
# 11  VIỆT NAM CÓ GIÚP CŨNG CHẲNG MUỐN KỂ CÔNG, SỰ T...
# 12  TQ có rất ít người tốt, người cực đoan thì nhi...
# 13  Nói gì thì nói\nVN mà sụp đổ bây giờ thg tàu c...
# 14  Viet nam da giup trung quocdanh tuong gioi tha...
# 15                   Cảm ơn bạ đã cho  biết thông tin
# 16  Bản tin này cần công bố rộng rãi để người TQ s...
# 17  Các bạn giúp chúng tôi trong kháng chiến chống...
# 18  Cần nói thêm 1 điều rất quan trọng: nhờ VN thắ...
# 19                             Nay vẫn còn ngọng nhỉ.
# 20  Mấy ông làm về tự hào Việt Nam hay xem video c...
# 21  Bạn biết tiếng TQ hãy thường xuyên viết và nói...
# 22  Cần phổ biến thông tin này bằng hai ngôn ngữ V...
# 23           bây giờ mới biết hôm nào chủu lại no nha
# 24  Người Việt chúng ta đã giúp ai thì giúp rất tr...
# 25  500 năm chắc Tq mới nói tốt về VN 1 lần còn hệ...
# 26  Bộ trưởng quốc phòng TQ vừa sang Việt Nam giải...
# 27  Kô có Mao thì kô có chế độ cộng sản Vn bây giờ...
# 28  Ồ thì ra là còn có chuyện lớn như vây của đất ...
# 29  Trung Quốc giúp Việt Nam đánh Mỹ, thực ra, cũn...
# 30  Trung quốc nó không giúp mình vô tư như liên x...
# 31  Tq và VN môi hở răng lạnh nhưng tq đã cắt môi ...
# 32  Giúp thì có giúp nhưng không thật tâm .bác hồ ...
# 33  Cuối cùng cũng có một người hiểu chuyện, chứ k...
# 34                     THÌ ra no mới là thằng VÔ ƠN !
# 35  Thuyết đômyno của mỹ chính là chặn sự phát tri...
# 36  nếu làm ra sản phẩm mà không có tiền để làm qu...
# 37  Kênh lên phiên bản tiếng trung nếu chủ đề về t...
# 38  Không có bình luận của dân mạng TQ về bài này ...
# 39  Giúp gì mà giúp, ở đây chưa biết ai giúp ai. T...
# 40  Admin nên tìm hiểu xem sau năm 79 đó, Trung Qu...
# 41  Phân tích của một vài cá nhân có đạo lý, nhưng...
# 91           Cam on nha su hoc TQ da noi len su that.
# 92  Và từ đó. bây giờ Việt nam ko làm đồng minh vớ...
# 93  Nói vậy người ta mới tôn trọng. Chứ cứ luận đi...
# 94  Trích báo mà éo trích các bình luận của dân TQ...
# 95                            Chúng ta đéo nợ gì nhau
# 96  Nói vn vô ơn còn trung quốc thì sao liên xô đã...
# 97  Sau khi pháp rút khỏi Việt Nam 1954 nó cũng để...
# 98  Lưỡng quốc tướng quân Nguyễn sơn cũng đã từng ...
# 99  Nguoi viet nam ngay nay co du nhan thuc va kho...
#
# [2.91 seconds] Done!
# Downloading Youtube comments for video: https://www.youtube.com/watch?v=UTjyYdmdcKw
#                                                  text
# 0   Cô vid không phải là vũ khí hủy diệt nhưng nó ...
# 1                  Quá vo vẫn 5 phút quản cáo một lần
# 2                                  Giống nói khó nghe
# 3      Lai toang benh dich vi nguoi tq nhu o Cam thoi
# 4   Dân quân biến của Trung Quốc nay lại có dân qu...
# 5   Thế chuyen gia trung quốc chắc chắn có bệnh ko...
# 6                               Có nên tiêm vacxin ko
# 7   Bệnh  viện  nhiệt  đới  là  tuyến  cuối  của  ...
# 8          Quảng cáo nhiều Như vậy thì ko đăng ký nua
# 9             Chào MC Thu Hiền, cô đọc rất rõ và hay!
# 10  Đang Theo giỏi thời sự thì quảng cáo nhảy vô đ...
# 11  sao ko tét dưới da trước có phai là ko chet ng...
# 12  Thaycochatchegidaumanhsongvoibenhsongomnguoich...
# 13                                          Adidaphat
# 14                   I wanna watch this video all day
# 15        Tin giả thì đừng có đăng có ngày sập kênh à
# 16  Cứ chuyên gia sang vn làm việc là có covid, li...
# 17              Tiêu đề ngớ ngẩn vậy . Dẹp kênh này .
# 18  M00m0mmm0p000000000000mm0p0000000000m00m00000m...
# 19                              Lần này thì toang rùi
# 20  trước hay sau nó cũng hết vấn đề thời gian thế...
# 21  bạn nói có ý đúng nhưng viết lỗi chính tả quá ...
# 22  Là do ng  thân đến chăm sóc lây chéo nhau khổ ...
# 23                                         M00000m0m0
# 24                                               M000
# 25  Dân đang no côviD mà sao cứ quảng cao thuốc kí...
# 26                                Chủ quan là toi rồi
# 27                      Chuẩn bị nhà hoả Thieu la vừa
# 28  Ai cung noi quản cáo nhiều... Ma sao toi xem m...
# 29  Đề nghị tiêm vac xin covid 19 bị chết ở An gia...
# 30                           mình sẽ không tiêm vácin
# 31                  Quảng cáo nhiều quá! Mất chất quá
# 32                     Giờ tiêm nữa là chết hàng loạt
# 33                        Truong hop nay phai su nang
# 34  Nghe mùi 3/ quá ơi...thôi...thôi bạn đừng có p...
# 35  Người TQ vào VN toàn đem theo điều chẳng tốt đ...
# 36  ban Thu Hien nay doc giong kho nghe qua, tui o...
# 37                               Còn nhiều và còn dài
# 38  Lỗi hoàn toàn do BV Nhiệt đới Trung Ương. Nếu ...
# 39  Campuchia tiep xuc voi chinaman from Wu Han, t...
# 40  Nhật cứ tổ chức Olympic là sẽ giống Ấn Độ đấy,...
# 41     Bệnh covit k lo,lo quảng cáo thuốc cường dương
# 42  không có vacxin thì sóng này qua thì són...
# 43  Nhân viên y tế vn chết sau khi tim vacien , mà...
